# %%
import json
import re
import requests

from typing import Any, Dict, List, Tuple

import pandas as pd

from bs4 import BeautifulSoup as bs

# %%
BASE_URL = "https://web.archive.org"
START_URL = "https://socialblade.com/youtube/top/category/entertainment"

CATEGORIES_DICT = {}
CHANNELS_DICT = {}

# %%
def comma_separated_to_num(string: str) -> int:
    if string is None:
        return None
    splits = [s.strip() for s in string.split(",")[::-1]]
    splits = [s for s in splits if s]
    num = 0
    base = 0
    for split in splits:
        num += int(split) * (10 ** base)
        base += len(split)
    return num

def short_form_to_num(short_form: str) -> int:
    if short_form is None:
        return None
    if short_form[-1].lower() == "k":
        multiplier = 1000
    elif short_form[-1].lower() == "m":
        multiplier = 1e6
    elif short_form[-1].lower() == "b":
        multiplier = 1e9
    else:
        try:
            return comma_separated_to_num(short_form)
        except Exception as e:
            print(short_form)
            raise e
    num = float(short_form[:-1].strip())
    return int(num * multiplier)

def find_sb_url(url: str) -> Tuple[str, str]:
    if url is None:
        return None, None
    pat = re.compile("\/web\/(\d+)\/(.*)")
    return re.search(pat, url).groups()

# %%
class Page:
    def __init__(self, name: str, url: str, archive_datetime: str):
        self.sb_url = url
        self.url = f"{BASE_URL}/web/{archive_datetime}/{url}"
        
    def process(self) -> List[Any]:
        raise NotImplementedError("Base Page can not process.")
        
    def _get_soup(self):
        try:
            response = requests.get(self.url)
        except requests.TooManyRedirects:
            print(f"Too many redirects for the URL {self.url}.")
            return None
        if response.status_code != 200:
            if "The Wayback Machine has not archived that URL." in response.text:
                print(f"The Wayback Machine has not archived the URL - {self.url}.")
                return None
            print(f"Error fetching page {self.url}")
            return None
            
        return bs(response.text, 'html.parser')

# %%
class Category(Page):
    def __init__(self, name: str, url: str, archive_datetime: str):
        super(Category, self).__init__(name, url, archive_datetime)
        self.url = f"{self.url}/mostsubscribed"
        print(f"processing URL {self.url}")
        self.channels = []
        self.channels_visited = {}
        
    def process(self) -> List[Dict[str, str]]:
        soup = self._get_soup()
        if not soup:
            return []
        else:
            left = soup.find("div", {"style": "float: left; width: 300px;"})
            right = soup.find("div", {"style": "float: right; width: 900px;"})
            self._add_channels(right)
            return self._other_categories(left)
    
    def _add_channels(self, root):
        global CHANNELS_DICT
        
        for channel_div in self._get_channel_divs(root):
            children = channel_div.findChildren("div", recursive=False)
            archive_date, sb_url = find_sb_url(children[2].find('a')['href'])
            if sb_url in CHANNELS_DICT:
                if not self.channels_visited.get(sb_url, False):
                    channel = CHANNELS_DICT[sb_url]
                else:
                    continue
            else:
                channel = Channel(children[2].find("a").text.strip(), sb_url, archive_date)
                channel.process()
                CHANNELS_DICT[sb_url] = channel
            self.channels_visited[sb_url] = True
            self.channels.append(channel)

    def _other_categories(self, root) -> List[Dict[str, str]]:
        others = []
        for div in self._get_category_divs(root):
            others.append(self._get_category_details(div))
        return others
    
    @staticmethod
    def _get_channel_divs(root):
        i = 0
        children = root.findChildren("div", recursive=False)
        for div in children:
            i += 1
            if div.attrs.get("id") == "sort-by":
                i += 1
                break
        return children[i:]
    
    @staticmethod
    def _get_category_divs(root):
        i = 0
        children = root.findChildren("div", recursive=False)
        for div in children:
            i += 1
            if div.text.strip() == 'Top 100 by Channeltype':
                break
        return children[i].find_all("a")
    
    @staticmethod
    def _get_category_details(cat_div):
        archive_date, sb_url = find_sb_url(cat_div["href"])
        return {
            "name": cat_div.text.strip(),
            "archive_datetime": archive_date,
            "url": sb_url
        }

# %%
class Channel(Page):
    def __init__(self, name: str, url: str, archive_datetime: str):
        super(Channel, self).__init__(name, url, archive_datetime)
        print(f"processing URL {self.url}")
        self.uploads = None
        self.subs = None
        self.views = None
        self.country = None
        self.country_archive_date = None
        self.country_url = None
        self.category = None
        self.category_archive_date = None
        self.category_url = None
        self.created_at = None
        self.grade = None
        self.sb_rank = None
        self.subs_rank = None
        self.vid_view_rank = None
        self.country_rank = None
        self.category_rank = None
        
    def process(self):
        soup = self._get_soup()
        if soup:
            top_info = soup.find("div", {"id": "YouTubeUserTopInfoWrap"})
            if top_info:
                self._set_top_info(top_info)
            user_content = soup.find("div", {"id": "socialblade-user-content"})
            if user_content:
                contents = user_content.findChildren("div", recursive=False)
                self._set_grade_rank(contents[0])
    
    def _set_top_info(self, root):
        avatar = root.find("img")["src"]
        info = root.find("div", {"id": "YouTubeUserTopInfoBlockTop"})
        info = info.find("div", {"id": "YouTubeUserTopInfoBlock"})
        info = info.find_all("div", {"class": "YouTubeUserTopInfo"})
        uploads = info[0].find_all("span")[1].text.strip()
        subs = info[1].find_all("span")[1].text.strip()
        views = info[2].find_all("span")[1].text.strip()
        country = info[3].find_all("span")[1].find("a")
        archive_date, url = find_sb_url(country["href"])
        category = info[4].find_all("span")[2].find("a")
        cat_archive_date, cat_url = find_sb_url(category["href"])

        self.uploads = comma_separated_to_num(uploads)
        self.subs = short_form_to_num(subs)
        self.views = comma_separated_to_num(views)
        self.country = country.text.strip()
        self.country_archive_date = archive_date
        self.country_url = url
        self.category = category.text.strip()
        self.category_archive_date = cat_archive_date
        self.category_url = cat_url
        self.created_at = info[5].find_all("span")[1].text.strip()
        
    def _set_grade_rank(self, root):
        grade, ranks = root.findChildren("div", recursive=False)
        ranks = ranks.findChildren("div", recursive=False)
        self.grade = grade.findChild("div", recursive=False).text.strip()
        self.sb_rank = ranks[0].find("p").text.strip()
        self.subs_rank = ranks[1].find("p").text.strip()
        self.vid_view_rank = ranks[2].find("p").text.strip()
        self.country_rank = ranks[3].find("p").text.strip()
        self.category_rank = ranks[4].find("p").text.strip()
        
    def serialize(self):
        return {
            "name": self.name,
            "url": self.url,
            "sb_url": self.sb_url,
            "uploads": self.uploads,
            "subs": self.subs,
            "views": self.views,
            "country": self.country,
            "country_url": self.country_url,
            "category": self.category,
            "cat_url": self.category_url,
            "created_at": self.created_at,
            "grade": self.grade,
            "sb_rank": self.sb_rank,
            "subs_rank": self.subs_rank,
            "vid_view_rank": self.vid_view_rank,
            "country_rank": self.country_rank,
            "category_rank": self.category_rank
        }

# %%
def process_category(name: str, url: str, archive_datetime: str):
    if url in CATEGORIES_DICT:
        return
    category = Category(name, url, archive_datetime)
    other_categories = category.process()
    CATEGORIES_DICT[url] = category
    print(len(CATEGORIES_DICT))
    for category in other_categories:
        process_category(**category)

# %%
process_category("Entertainment", START_URL, "20210318122140")
# Out:
# processing URL https://web.archive.org/web/20210318122140/https://socialblade.com/youtube/top/category/entertainment/mostsubscribed
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/set-india
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/kids-diana-show
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/channel/UCJplp5SjeGSdVdwsfb9Q7lQ
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/vladandniki
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/user/zeetv
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/mrbeast6000
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/sonysab
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/badabunoficials
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/holasoygermna
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/felipe-neto
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/felipe-neto.
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/katyperry.
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/elrubiusomg
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/vcsabiavideos
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/theellenshow
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/channel/UCS94J1s6-qc8v7btCdS2pNg
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/rihanna~
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/colorstv\\\\\\\\\\\\\\\\
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/getmovies
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/getmovies.
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/luccasneto{
# Too many redirects for the URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/luccasneto{.
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/abs-cbn-entertainment
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/workpointofficial
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/toysandcolors
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/shemaroo
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/luisfonsiofficial
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/user/rezendeevil
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/ryantoysreview
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/a4a4a4a4
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/one31official
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/루체테
# Too many redirects for the URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/루체테.
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/channel/UCpEJRZdSpdVZ8vh63T9I2KQ
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/ch3thailand
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/ch3thailand.
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/ultrahindi
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/erosentertainment
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/attahalilintar
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/user/thelatelateshow
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/user/toypudding
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/jamescharles
# Too many redirects for the URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/jamescharles.
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/sssniperwolf]
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/mariaclaraejp
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/vootkids
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/ricisofficial1795
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/mojo
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/1milliondancestudioofficial
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/lucasandmarcus
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/loganpaul-vlogs
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/loganpaul-vlogs.
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/collinskey
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/amit-bhadana
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/amit-bhadana.
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/ratitaspandilleras
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/gma-network
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/gma-network.
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/1-thek
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/renatogarciapr
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/wowkidztv
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/ryanhiga
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/littleangelvideo
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/sonypal
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/mrmaxlife
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/re-act
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/re-act.
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/sesamestreet
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/channel/UCcartHVtvAUzfajflyeT_Gg
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/channel/UCjZ-Ekz7JDN6GDXwusvSHvg
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/ransentertainment
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/mmoshaya
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/zhcomicart
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/netflix
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/nbcagt
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/channel/UC4JCksJF76g_MdzPVBJoC3Q
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/venusmovies
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/venusmovies.
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/channel/UC5ma-WCc8jNCV0WyRnfbHTg
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/trans7official
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/slivkichanel\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/slivkichanel\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\.
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/orugrat\\\\
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/baimpaula
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/lizakoshy
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/jimmykimmellive
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/disneyla
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/channel/UCqNmJfc7RgMU6hTxOOuCYHQ
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/noorstars
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/genhalilintar
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/mnet
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/infinitelists
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/gordonramsay)
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/rhettandlink2
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/toysandlittlegaby
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/user/gooodlifefilms
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/ckntoys
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/eeoneguy
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/natgeo\
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/werevertumorro,
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/werevertumorro,.
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/demi
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/portadosfundos,
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/portadosfundos,.
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/kidstvsongs
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/kidstvsongs.
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/gottalentglobal
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/guava-juice
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/user/britainsgottalent09
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/channel/UCtm3DGXkWqAUQZMHl97SVxA
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/fatosdesconhecidos
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/telenovelatelevisa
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/preston-playz
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/pdkfilms
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/c/indosiar
# 1
# processing URL https://web.archive.org/web/20210301042225/https://socialblade.com/youtube/top/category/autos/mostsubscribed
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/topgear
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/chris-fix
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/trendchannel
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/jucaviapri
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/user/dima91gordey
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/brijnaarisumi
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/supercarblondie
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/car-wow
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/car-wow.
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/user/academeg
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/donutmediatv
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/cgpgrey
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/thehoonigans
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/-salomundo
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/-salomundo.
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/smotra-tv
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/smotra-tv.
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/channel/UCpzPENOZcyAsKD6aBK0FLAw
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/ильдаравтоподбор
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/ильдаравтоподбор.
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/scottykilmermechanic
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/dougdemuro
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/user/fulllux
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/гараж54
# Error fetching page https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/гараж54
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/mightycarmods
# Error fetching page https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/mightycarmods
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/djmedic2008
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/happyprincegaming
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/felixladen
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/jaylenosgarage
# Error fetching page https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/jaylenosgarage
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/adamlz
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/thestradman\
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/thestradman\.
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/1320videos
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/carthrottle
# Error fetching page https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/carthrottle
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/explained
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/user/bayancover
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/user/dailydrivenexotics
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/arabgt
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/aln1533
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/aln1533.
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/channel/UCVqJYFWsnkLEUkmmS-avyQg
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/autotopnl
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/zygy3mr
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/user/wilimovich
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/vicesat
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/ttheeverythingg
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/user/ridwanhr
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/channel/UC3tpaXFBF99yzfXVTYnCD7Q
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/motozip
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/shm,ee150
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/user/vehiclevirgins
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/user/alfredovlza
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/xracingvideos
# Error fetching page https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/xracingvideos
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/youcarpress
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/gumbal
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/ford
# Error fetching page https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/ford
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/thedetailgeek
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/thedetailgeek.
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/powerdriftofficial
# Error fetching page https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/powerdriftofficial
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/asatachannel
# Error fetching page https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/asatachannel
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/jppgmbh
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/xehay
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/user/motoroctane
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/pramodslife
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/channel/UCA6VNcthvobYO48O1AIMQQg
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/user/drive
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/tjhunt28
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/العالميةلصيانةالسياراتجدة
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/العالميةلصيانةالسياراتجدة.
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/teslamotors
# Error fetching page https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/teslamotors
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/fitraeri
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/yiannimize
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/user/tavarish
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/user/stopxamlive
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/channel/UCyAwIVbVWB9JCpJYfjIN7LQ
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/denislegostaev2015
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/denislegostaev2015.
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/autocarindia1
# Error fetching page https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/autocarindia1
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/drivetribe
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/مصطفىحسن1
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/مصطفىحسن1.
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/user/ammonycdotcom
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/lamborghini
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/lamborghini.
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/dogankabak
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/salomondrin~~
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/channel/UCagrVjJhSVXzPlQ4Hdh6zng
# Error fetching page https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/channel/UCagrVjJhSVXzPlQ4Hdh6zng
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/channel/UCWG4JNqznyFXWQVqVt0apmQ
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/channel/UCWG4JNqznyFXWQVqVt0apmQ.
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/dshomemade
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/dshomemade.
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/outlaw-dipper
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/outlaw-dipper.
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/rcrcrc
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/user/canaldofoguinho
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/cartvpress
# Error fetching page https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/cartvpress
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/mercedes-benz
# The Wayback Machine has not archived the URL - https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/mercedes-benz.
# processing URL https://web.archive.org/web/20210301042114/https://socialblade.com/youtube/c/acelerados
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_41409/2293172790.py in <module>
# ----> 1 process_category("Entertainment", START_URL, "20210318122140")
#
# /tmp/ipykernel_41409/1301761572.py in process_category(name, url, archive_datetime)
#       7     print(len(CATEGORIES_DICT))
#       8     for category in other_categories:
# ----> 9         process_category(**category)
#
# /tmp/ipykernel_41409/1301761572.py in process_category(name, url, archive_datetime)
#       3         return
#       4     category = Category(name, url, archive_datetime)
# ----> 5     other_categories = category.process()
#       6     CATEGORIES_DICT[url] = category
#       7     print(len(CATEGORIES_DICT))
#
# /tmp/ipykernel_41409/121584907.py in process(self)
#      14             left = soup.find("div", {"style": "float: left; width: 300px;"})
#      15             right = soup.find("div", {"style": "float: right; width: 900px;"})
# ---> 16             self._add_channels(right)
#      17             return self._other_categories(left)
#      18
#
# /tmp/ipykernel_41409/121584907.py in _add_channels(self, root)
#      30             else:
#      31                 channel = Channel(children[2].find("a").text.strip(), sb_url, archive_date)
# ---> 32                 channel.process()
#      33                 CHANNELS_DICT[sb_url] = channel
#      34             self.channels_visited[sb_url] = True
#
# /tmp/ipykernel_41409/35251397.py in process(self)
#      25             top_info = soup.find("div", {"id": "YouTubeUserTopInfoWrap"})
#      26             if top_info:
# ---> 27                 self._set_top_info(top_info)
#      28             user_content = soup.find("div", {"id": "socialblade-user-content"})
#      29             if user_content:
#
# /tmp/ipykernel_41409/35251397.py in _set_top_info(self, root)
#      42         archive_date, url = find_sb_url(country["href"])
#      43         category = info[4].find_all("span")[2].find("a")
# ---> 44         cat_archive_date, cat_url = find_sb_url(category["href"])
#      45
#      46         self.uploads = comma_separated_to_num(uploads)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
len(CATEGORIES_DICT), len(CHANNELS_DICT)
# Out:
# (1, 183)

# %%
list(CHANNELS_DICT.values())[0].serialize()
# Out:
# {'uploads': 51750,
#  'subs': 98900000,
#  'views': 81559621102,
#  'country': 'IN',
#  'country_archive_date': '20210318120511',
#  'country_url': 'https://socialblade.com/youtube/top/country/in',
#  'category': 'Entertainment',
#  'cat_archive_date': '20210318120511',
#  'cat_url': 'https://socialblade.com/youtube/top/category/entertainment',
#  'created_at': 'Sep 20th, 2006',
#  'grade': 'A++',
#  'sb_rank': '3rd',
#  'subs_rank': '6th',
#  'vid_view_rank': '3rd',
#  'country_rank': '2nd',
#  'category_rank': '1st'}

# %%
def get_channel_df():
    data = []
    for channel in CHANNELS_DICT.values():
        data.append(channel.serialize())
    return pd.DataFrame.from_records(data)

df = get_channel_df()
df.head()
# Out:
#    uploads        subs         views country country_archive_date  \
# 0  51750.0  98900000.0  8.155962e+10      IN       20210318120511
# 1    831.0  75700000.0  5.285933e+10      US       20210316082321
# 2    548.0  70300000.0  5.327943e+10      US       20210228122718
# 3    330.0  63100000.0  4.412348e+10      US       20210225134935
# 4  67367.0  57200000.0  2.787377e+10      IN       20210304092457
#
#                                       country_url       category  \
# 0  https://socialblade.com/youtube/top/country/in  Entertainment
# 1  https://socialblade.com/youtube/top/country/us           Film
# 2  https://socialblade.com/youtube/top/country/us  Entertainment
# 3  https://socialblade.com/youtube/top/country/us  Entertainment
# 4  https://socialblade.com/youtube/top/country/in  Entertainment
#
#   cat_archive_date                                            cat_url  \
# 0   20210318120511  https://socialblade.com/youtube/top/category/e...
# 1   20210316082321  https://socialblade.com/youtube/top/category/film
# 2   20210228122718  https://socialblade.com/youtube/top/category/e...
# 3   20210225134935  https://socialblade.com/youtube/top/category/e...
# 4   20210304092457  https://socialblade.com/youtube/top/category/e...
#
#        created_at grade sb_rank subs_rank vid_view_rank country_rank  \
# 0  Sep 20th, 2006   A++     3rd       6th           3rd          2nd
# 1  May 12th, 2015   A++     4th       8th           7th          3rd
# 2   Dec 6th, 2016   A++     6th      12th           6th          6th
# 3  Apr 23rd, 2018   A++     7th      15th          11th          7th
# 4  Dec 11th, 2005   A++     8th      18th           4th          4th
#
#   category_rank
# 0           1st
# 1           2nd
# 2           3rd
# 3           4th
# 4           5th

# %%
df.to_csv("channels.csv", index=False)
